# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\e006697\\Documents\\Python_2\\CursoPython\\Python Data Science\\Fuentes Kike\\Base de datos\\base_datos_2008.csv", nrows=1e6) #1e6 es 10 elevado a la 6. 1 millon de filas

# %%
dfdupli = df.append(df) #Creamos un nuevo df para poder hacer las pruebas y trabajar sobre el

# %%
dfdupli = dfdupli.sample (frac=1) #Lo reordenamos

# %%
dfclean = dfdupli.drop_duplicates() #Eliminamos los duplicados con la función drop_duplicates()

# %%
len(dfclean)
# Out:
# 999996

# %%
len(dfclean) == len(df)
# Out:
# False

# %%
dfclean.drop_duplicates(subset = "DayofMonth") #Eliminaria duplicados por la columna DayofMonth, dejando solo una fila por cada valor distinto de esta columna
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 76970   2008      1          26          6   1807.0        1810   2043.0
# 963197  2008      2          12          2   1604.0        1605   1640.0
# 378373  2008      1           6          7   1144.0        1145   1236.0
# 450023  2008      1          17          4   1225.0        1215   1347.0
# 596075  2008      1           7          1   2044.0        2020   2240.0
# 324157  2008      1          25          5   1323.0        1321   1440.0
# 303579  2008      1          16          3   1054.0        1100   1247.0
# 952318  2008      2          20          3   1911.0        1906   2052.0
# 104087  2008      1          30          3   1322.0        1220   1554.0
# 323899  2008      1          31          4   1337.0        1340   1520.0
# 660872  2008      2          19          2    848.0         845    856.0
# 375591  2008      1          29          2    623.0         625    656.0
# ...

# %%
df.dropna() #eliminamos los registros que tengan algun valor NaN
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %%
df.dropna(thresh=25) #le decimos que elimne las filas donde no hayan 25 columnas o mas, informadas sin NaN
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4       2008      1           3          4   1829.0        1755   1959.0
# 6       2008      1           3          4   1937.0        1830   2037.0
# 11      2008      1           3          4   1644.0        1510   1845.0
# 16      2008      1           3          4   1452.0        1425   1640.0
# 18      2008      1           3          4   1323.0        1255   1526.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999973  2008      2          23          6   1306.0        1235   1514.0
# 999983  2008      2          28          4   1458.0        1235   1645.0
# 999988  2008      2           4          1   1754.0        1655   2056.0
# 999989  2008      2           5          2   1812.0        1655   2129.0
# 999994  2008      2          11          1   1717.0        1655   2030.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.dropna(thresh=len(df.columns)-1) #solo deja los que solo tienen una columna como NaN
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4       2008      1           3          4   1829.0        1755   1959.0
# 6       2008      1           3          4   1937.0        1830   2037.0
# 11      2008      1           3          4   1644.0        1510   1845.0
# 16      2008      1           3          4   1452.0        1425   1640.0
# 18      2008      1           3          4   1323.0        1255   1526.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999973  2008      2          23          6   1306.0        1235   1514.0
# 999983  2008      2          28          4   1458.0        1235   1645.0
# 999988  2008      2           4          1   1754.0        1655   2056.0
# 999989  2008      2           5          2   1812.0        1655   2129.0
# 999994  2008      2          11          1   1717.0        1655   2030.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.dropna(subset = ["CancellationCode"]) #indicar por que columna debemos filtrar los que no tengan NaN
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178     2008      1           3          4      NaN         700      NaN
# 373     2008      1           3          4      NaN        1100      NaN
# 399     2008      1           3          4      NaN         905      NaN
# 401     2008      1           3          4      NaN        1620      NaN
# 415     2008      1           3          4      NaN        1930      NaN
# ...      ...    ...         ...        ...      ...         ...      ...
# 999913  2008      2          11          1      NaN         855      NaN
# 999919  2008      2          17          7      NaN         855      NaN
# 999961  2008      2          17          7      NaN        1445      NaN
# 999971  2008      2          22          5      NaN        1235      NaN
# 999999  2008      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...
